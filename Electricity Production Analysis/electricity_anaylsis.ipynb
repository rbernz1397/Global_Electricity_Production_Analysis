# %%
# Imports for Analysis
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
import hvplot.pandas

# Imports for API 
import requests
import json
from api_keys import geoapify_key
from api_keys import api_ninjas_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e41a9341-254c-413e-90c2-d093a5b22dc1" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Import the csv file
file_path = './Resources/global_electricity_production_data.csv'
original_df = pd.read_csv(file_path)

# Create a column for the year
original_df['Year'] = original_df['date'].str.split('/').str[-1]

# Display the first 12 rows to show all of the different products
original_df.head(13)
# Out:
#    country_name       date                       parameter  \
# 0     Australia  12/1/2023      Net Electricity Production
# 1     Australia  12/1/2023      Net Electricity Production
# 2     Australia  12/1/2023      Net Electricity Production
# 3     Australia  12/1/2023      Net Electricity Production
# 4     Australia  12/1/2023      Net Electricity Production
# 5     Australia  12/1/2023      Net Electricity Production
# 6     Australia  12/1/2023      Net Electricity Production
# 7     Australia  12/1/2023      Net Electricity Production
# 8     Australia  12/1/2023      Net Electricity Production
# 9     Australia  12/1/2023      Net Electricity Production
# 10    Australia  12/1/2023         Used for pumped storage
# 11    Australia  12/1/2023             Distribution Losses
# 12    Australia  12/1/2023  Final Consumption (Calculated)
#
#                                               product       value unit  Year
# ...

# %% [markdown]
# # How does the US compare to other countries in terms of electricity production?

# %%
# Filter the raw dataframe down to only total production of electricity
production_filter = (original_df['parameter'] == 'Net Electricity Production')&(original_df['product']=='Electricity')
production_df = original_df[production_filter]

# Display dataframe
production_df.head()
# Out:
#    country_name       date                   parameter      product  \
# 0     Australia  12/1/2023  Net Electricity Production  Electricity
# 13      Austria  12/1/2023  Net Electricity Production  Electricity
# 31      Belgium  12/1/2023  Net Electricity Production  Electricity
# 49       Canada  12/1/2023  Net Electricity Production  Electricity
# 68        Chile  12/1/2023  Net Electricity Production  Electricity
#
#          value unit  Year
# 0   22646.1901  GWh  2023
# 13   6783.2730  GWh  2023
# 31   6799.1069  GWh  2023
# 49  55982.2209  GWh  2023
# 68   7734.9912  GWh  2023

# %%
# Group the dataframe by country and sum the value
production_by_country = production_df.groupby(['country_name','Year'])['value'].sum()
production_by_country_df = production_by_country.reset_index()

# Disable scientific notation
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Display dataframe
production_by_country_df.head()
# Out:
#   country_name  Year     value
# 0    Argentina  2015 137590.83
# 1    Argentina  2016 139172.17
# 2    Argentina  2017 137915.23
# 3    Argentina  2018 139188.12
# 4    Argentina  2019 132462.31

# %%
# Filter down to the electricity production for 2023
production_by_country_2023_df = production_by_country_df[production_by_country_df['Year']=='2023']

# Drop unneeded year column
production_by_country_2023_df = production_by_country_2023_df.drop(columns='Year')

# Display first 5 rows in dataframe
production_by_country_2023_df.head()
# Out:
#    country_name     value
# 8     Argentina 130607.86
# 22    Australia 261570.59
# 36      Austria  67958.49
# 50      Belgium  78668.68
# 59       Brazil 690334.72

# %%
# Sort values
sorted_production_by_country_2023_df = production_by_country_2023_df.sort_values('value', ascending=False)

# Create a bar plot of all countries elerticity production in 2023
fig, ax = plt.subplots(figsize=(30,15))
ax.bar(sorted_production_by_country_2023_df['country_name'], sorted_production_by_country_2023_df['value'])

# Create a bar of just the US to highlight the US
ax.bar(sorted_production_by_country_2023_df['country_name'][598], sorted_production_by_country_2023_df['value'][598])

# Create labels
ax.set_xticks(ticks=sorted_production_by_country_2023_df['country_name'],labels=sorted_production_by_country_2023_df['country_name'],rotation_mode='anchor',ha='right', rotation=45)
ax.set_xlabel('Countries')
ax.set_ylabel('Electricity Output in Millions (GWh)')
ax.set_title('Electricity Production of Countries (2023)')
ax.set_xlim(-1, 48)

# Save image to output folder
fig.savefig('./output_data/electricity_2023_comparison.png')

# Display the plot
plt.show()

# %%
# Create lists for the latitudes and longitudes of each country
list_of_lats = []
list_of_lons = []

# Loop through Geoapify and extract the latitudes and longitudes of each country
for country in production_by_country_2023_df['country_name']:
    # Collect JSON request for a country in the dataframe
    query_url = f"https://api.geoapify.com/v1/geocode/search?country={country}&format=json&apiKey={geoapify_key}"
    json_response = requests.get(query_url).json()

    # Extract the lat and lons
    lat_response = json_response['results'][0]['lat']
    lon_response = json_response['results'][0]['lon']

    # Add them to each list
    list_of_lats.append(lat_response)
    list_of_lons.append(lon_response)

# Add the lats and lons to the dataframe
production_by_country_2023_df['lat'] = list_of_lats
production_by_country_2023_df['lon'] = list_of_lons

# Display dataframe
production_by_country_2023_df.head()
# Out:
#    country_name     value    lat    lon
# 8     Argentina 130607.86 -35.00 -64.97
# 22    Australia 261570.59 -24.78 134.75
# 36      Austria  67958.49  47.59  14.12
# 50      Belgium  78668.68  50.64   4.67
# 59       Brazil 690334.72 -10.33 -53.20

# %%
# Create list for the population of each country
population_list = []

# Loop through api ninja and extract the population of each country
for country in production_by_country_2023_df['country_name']:
    # Collect JSON request for a country in the dataframe
    ninja_url = f"https://api.api-ninjas.com/v1/country?name={country}&X-Api-Key={api_ninjas_key}"
    json_response = requests.get(ninja_url).json()

    # Extract the population
    pop_response = json_response[0]['population']*1000

    # Add them to each list
    population_list.append(pop_response)

# Add the lats and lons to the dataframe
production_by_country_2023_df['Population'] = population_list

# Display dataframe
production_by_country_2023_df.head()
# Out:
#    country_name     value    lat    lon   Population
# 8     Argentina 130607.86 -35.00 -64.97  45196000.00
# 22    Australia 261570.59 -24.78 134.75  25500000.00
# 36      Austria  67958.49  47.59  14.12   9006000.00
# 50      Belgium  78668.68  50.64   4.67  11590000.00
# 59       Brazil 690334.72 -10.33 -53.20 212559000.00

# %%
# Configure the map plot of each country with size based on electricity production in 2023
map_plot_1 = production_by_country_2023_df.hvplot.points('lon', 
                                          'lat', 
                                          geo=True,
                                          hover_cols=['country_name', 'value','lat', "lon", 'Population'],
                                          tiles='OSM',
                                          frame_width = 700,
                                          frame_height = 500,
                                          color ='country_name',
                                          size='value',
                                          alpha=.5,
                                          scale = .025)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [lon,lat]   (country_name,value,Population)

# %% [markdown]
# ### Summary Statistics for the Countries in 2023

# %%
# Total counts grouped by country for 2023
total_electricity_2023 = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Electricity')&(original_df['Year']=='2023')].groupby('country_name')['value'].sum()
total_renewables_2023 = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Total Renewables (Hydro, Geo, Solar, Wind, Other)')&(original_df['Year']=='2023')].groupby('country_name')['value'].sum()
total_combustible_fuels_2023 = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Total Combustible Fuels')&(original_df['Year']=='2023')].groupby('country_name')['value'].sum()
combustible_renewables_2023 = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Combustible Renewables')&(original_df['Year']=='2023')].groupby('country_name')['value'].sum()
nonrenewable_combustible_fuels = total_combustible_fuels_2023-combustible_renewables_2023
nuclear_2023 = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Nuclear')&(original_df['Year']=='2023')].groupby('country_name')['value'].sum()
country_population = production_by_country_2023_df.groupby('country_name')['Population'].sum()

# Percents of electricity production using renewable, non-renewable combustible, and nuclear for 2023
percent_renewables_2023 = total_renewables_2023/total_electricity_2023*100
percent_nonrewable_2023 = nonrenewable_combustible_fuels/total_electricity_2023*100
percent_nuclear_2023 = nuclear_2023/total_electricity_2023*100

# The amount of electricity produced per person in MWh for 2023
electric_per_person = total_electricity_2023*1000/country_population

# Create a dataframe of summary statistics 
summary_statistics_2023 = pd.DataFrame({
    "Total Electricity Production (GWh)":total_electricity_2023,
    "Country Population": country_population,
    "Electricity Per Person (MWh)": electric_per_person,
    "% Renewable": percent_renewables_2023,
    "% Non-Renewable Combustible": percent_nonrewable_2023,
    "% Nuclear": percent_nuclear_2023,
})

# Replace NaN values with zeros
summary_statistics_2023 = summary_statistics_2023.fillna(0)

# Display the dataframe
summary_statistics_2023.index.name = None
summary_statistics_2023
# Out:
#                  Total Electricity Production (GWh)  Country Population  \
# Argentina                                 130607.86         45196000.00
# Australia                                 261570.59         25500000.00
# Austria                                    67958.49          9006000.00
# Belgium                                    78668.68         11590000.00
# Brazil                                    690334.72        212559000.00
# Bulgaria                                   36645.54          6948000.00
# Canada                                    614848.40         37742000.00
# Chile                                      90521.96         19116000.00
# China                                    9093177.33       1439324000.00
# Colombia                                   86562.78         50883000.00
# Costa Rica                                 11418.22          5094000.00
# Croatia                                    17212.62          4105000.00
# ...

# %%
# Create a box plot
fig, ax = plt.subplots()
ax.boxplot(summary_statistics_2023['Electricity Per Person (MWh)'],
           flierprops=dict(marker='o', markerfacecolor='red', markersize=8))

# Create labels and titles
ax.set_ylabel('Electricity (MWh)')
ax.set_title('Electricity Per Person (MWh)')
ax.set_xticks(ticks=[1], labels=['Countries'])

# Save graph as PNG file
fig.savefig('./output_data/electricity_per_person_boxplot.png')

# Show plot
plt.show()

# %%
# Function to calculate the interquartile range
def IQR(your_data):
    q1 = stats.scoreatpercentile(your_data, 25)
    q3 = stats.scoreatpercentile(your_data, 75)
    return q3 - q1

# Function to calculate the upper bound of the data for outliers
def upper_bound(your_data):
    q3 = stats.scoreatpercentile(your_data, 75)
    iqr = IQR(your_data)
    return q3 + iqr*1.5

# Function to calculate the lower bound of the data for outliers
def lower_bound(your_data):
    q1 = stats.scoreatpercentile(your_data, 25)
    iqr = IQR(your_data)
    return q1 - iqr*1.5

# Function to find the IQR and outliers in a data set
def outliers_with_IQR(name, your_data):
    flag = False
    outliers_list = []
    for item in your_data:
        if item < lower_bound(your_data) or upper_bound(your_data) < item:
            flag = True
            outliers_list.append(round(item,2))
    if flag == False:
        print(f"{name} has an IQR of {IQR(your_data).round(2)} and has no outliers.")
    else:
        print(f"{name} has an IQR of {IQR(your_data).round(2)} and its potential outliers are: {outliers_list}")

# Print out the IQR and outliers for electricity output per person
outliers_with_IQR('The data set', summary_statistics_2023['Electricity Per Person (MWh)'])
# Out:
# The data set has an IQR of 3.99 and its potential outliers are: [16.29, 14.29, 58.19, 22.86, 28.39, 15.93]

# %%
# Create mean and median values for the 48 countries in the dataset
mean_electric_production = summary_statistics_2023['Total Electricity Production (GWh)'].mean()
median_electric_production = summary_statistics_2023['Total Electricity Production (GWh)'].median()

mean_population = summary_statistics_2023['Country Population'].mean()
median_population = summary_statistics_2023['Country Population'].median()

mean_electric_per_person = summary_statistics_2023['Electricity Per Person (MWh)'].mean()
median_electric_per_person = summary_statistics_2023['Electricity Per Person (MWh)'].median()

mean_percent_renewables = summary_statistics_2023['% Renewable'].mean()
median_percent_renewables = summary_statistics_2023['% Renewable'].median()

# Create a dataframe of measure of center statistics 
measure_of_center_statistics_2023 = pd.DataFrame({
    "Mean Electricity Production (GWh)": [mean_electric_production],
    "Median Electricity Production (GWh)":[median_electric_production],
    "Mean Country Population": [mean_population],
    "Median Country Population": [median_electric_production],
    "Mean Electricity Per Person (MWh)": [mean_electric_per_person],
    "Median Electricity Per Person (MWh)": [median_electric_per_person],
    "Mean % Renewable": [mean_percent_renewables],
    "Median % Renewable": [median_percent_renewables]
})

# Display measure of center statistics
measure_of_center_statistics_2023
# Out:
#    Mean Electricity Production (GWh)  Median Electricity Production (GWh)  \
# 0                          469934.76                             76477.58
#
#    Mean Country Population  Median Country Population  \
# 0              93101625.00                   76477.58
#
#    Mean Electricity Per Person (MWh)  Median Electricity Per Person (MWh)  \
# 0                               7.72                                 5.12
#
#    Mean % Renewable  Median % Renewable
# 0             51.10               47.47

# %%
# Monthly averages grouped by country name for 2023
total_combustible_fuels_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Total Combustible Fuels')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()
coal_peat_and_manufactured_gases_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Coal, Peat and Manufactured Gases')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()
oil_and_petroleum_products_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Oil and Petroleum Products')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()
natural_gas_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Natural Gas')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()
combustible_renewables_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Combustible Renewables')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()
hydro_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Hydro')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()
wind_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Wind')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()
solar_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Solar')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()
total_renewables_2023_average = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Total Renewables (Hydro, Geo, Solar, Wind, Other)')&(original_df['Year']=='2023')].groupby('country_name')['value'].mean()

# Create a dataframe of averages 
monthly_averages_2023 = pd.DataFrame({
    "Total Combustible Fuels (Monthly AVG)":total_combustible_fuels_2023_average,
    "Coal, Peat and Manufactured Gases (Monthly AVG)": coal_peat_and_manufactured_gases_2023_average,
    "Oil and Petroleum Products (Monthly AVG)": oil_and_petroleum_products_2023_average,
    "Natural Gas (Monthly AVG)":natural_gas_2023_average,
    "Combustible Renewables (Monthly AVG)": combustible_renewables_2023_average,
    "Hydro (Monthly AVG)": hydro_2023_average,
    "Wind (Monthly AVG)": wind_2023_average,
    "Solar (Monthly AVG)": solar_2023_average,
    "Total Renewables (Monthly AVG)": total_renewables_2023_average
})

# replace NaN values with zeros
monthly_averages_2023 = monthly_averages_2023.fillna(0)

# Display the dataframe
monthly_averages_2023.index.name = None
monthly_averages_2023
# Out:
#                  Total Combustible Fuels (Monthly AVG)  \
# Argentina                                      6858.20
# Australia                                     13824.25
# Austria                                        1239.09
# Belgium                                        1913.66
# Brazil                                         9306.67
# Bulgaria                                       1113.45
# Canada                                        10056.31
# Chile                                          3021.69
# China                                        496308.54
# Colombia                                       2612.50
# Costa Rica                                        8.02
# Croatia                                         494.28
# Cyprus                                          340.65
# Czech Republic                                 2940.09
# Denmark                                         917.71
# Estonia                                         294.25
# ...

# %% [markdown]
# # How does population impact electricity production?

# %%
# linear regression population vs electrity production
x_values = summary_statistics_2023["Country Population"]
y_values = summary_statistics_2023["Total Electricity Production (GWh)"]
slope, intercept, r, p, se = stats.linregress(x_values, y_values)

# Create regression values and regression line
regress_values = slope*x_values+intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,2))

# Display the r-value above the graph
print(f"The r-value is {round(r,2)}")

# Create a plot
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=False)
ax1.scatter(x_values, y_values)
ax1.plot(x_values, regress_values, color='red')
ax2.scatter(x_values, y_values)
ax2.plot(x_values, regress_values, color='red')
ax3.scatter(x_values, y_values)
ax3.plot(x_values, regress_values, color='red')

# Add labels
ax1.set_xlabel('Population (Billions)')
ax1.set_ylabel('Electricity (GWh)')
ax1.set_title('Population Vs. Total Electrical Output in 2023')
ax2.set_ylabel('Electricity (GWh)')
ax2.set_ylim(0, 1250000)
ax2.set_xlim(0, 250000000)
ax3.set_xlabel('Population')
ax3.set_ylabel('Electricity (GWh)')
ax3.set_xlim(300000000,1500000000)

# Display the equation
ax1.annotate(line_eq,(0,8000000),fontsize=15,color="red")

# Save as PNG file
fig.savefig("./output_data/pop_vs_total_elec_2023.png")

# Display the plot
plt.show()
# Out:
# The r-value is 0.81

# %%
# linear regression population vs electrity production
x_values = summary_statistics_2023["Country Population"]
y_values = summary_statistics_2023["% Non-Renewable Combustible"]
slope, intercept, r, p, se = stats.linregress(x_values, y_values)

# Create regression values and regression line
regress_values = slope*x_values+intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,2))

# Display the r-value above the graph
print(f"The r-value is {round(r,2)}")

# Create a plot
fig, ax2 = plt.subplots()
ax2.scatter(x_values, y_values)
ax2.plot(x_values, regress_values, color='red')

# Add labels
ax2.set_xlabel('Population (Billions)')
ax2.set_ylabel('Percentage of Non-Renewables')
ax2.set_title('Population Vs. Percentage of Non-Renewables in 2023')

# Display the equation
ax2.annotate(line_eq,(0,0),fontsize=15,color="red")

# Save as PNG file
fig.savefig("./output_data/pop_vs_non_renew_2023.png")

# Display the plot
plt.show()
# Out:
# The r-value is 0.31

# %%
# linear regression population vs electrity production
x_values = summary_statistics_2023["Country Population"]
y_values = summary_statistics_2023["% Renewable"]
slope, intercept, r, p, se = stats.linregress(x_values, y_values)

# Create regression values and regression line
regress_values = slope*x_values+intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,2))

# Display the r-value above the graph
print(f"The r-value is {round(r,2)}")

# Create a plot
fig, ax2 = plt.subplots()
ax2.scatter(x_values, y_values)
ax2.plot(x_values, regress_values, color='red')

# Add labels
ax2.set_xlabel('Population (Billions)')
ax2.set_ylabel('Percentage of Renewables')
ax2.set_title('Population Vs. Percentage of Renewables in 2023')

# Display the equation
ax2.annotate(line_eq,(200000000,80),fontsize=15,color="red")

# Save as PNG file
fig.savefig("./output_data/pop_vs_renew_2023.png")

# Display the plot
plt.show()
# Out:
# The r-value is -0.23

# %% [markdown]
# # How do the ratios of non-rewenable fuel vs renewables for electricity compare in countries?

# %% [markdown]
# ### Bottom 10 Performing Countries Based on Renewables Used for Electricity

# %%
# Creates a dataframe from the summary statistics to show the bottom 10 based on renewable percentage
worst_percent_renewables = summary_statistics_2023.sort_values('% Renewable', ascending=True)

# Creating a copy for plotting later
worst_columns_for_plot = worst_percent_renewables[['% Renewable','% Non-Renewable Combustible','% Nuclear']].copy().iloc[:10,:]

# Format numbers for better readability
worst_percent_renewables['Total Electricity Production (GWh)'] = worst_percent_renewables['Total Electricity Production (GWh)'].map('{:,.2f}'.format)
worst_percent_renewables['Country Population'] = worst_percent_renewables['Country Population'].map('{:,.0f}'.format)
worst_percent_renewables['% Renewable'] = worst_percent_renewables['% Renewable'].map('{:.0f}%'.format)
worst_percent_renewables['% Nuclear'] = worst_percent_renewables['% Nuclear'].map('{:.0f}%'.format)
worst_percent_renewables['% Non-Renewable Combustible'] = worst_percent_renewables['% Non-Renewable Combustible'].map('{:.0f}%'.format)

# Display the first 10 rows in the dataframe
worst_percent_renewables.head(10)
# Out:
#                Total Electricity Production (GWh) Country Population  \
# Korea                                  589,428.61         25,779,000
# Malta                                    2,231.05            442,000
# Mexico                                 402,880.70        128,933,000
# Czech Republic                          70,516.83         10,709,000
# Cyprus                                   5,124.54          1,207,000
# India                                1,802,220.14      1,380,004,000
# United States                        4,254,837.17        331,003,000
# Japan                                  977,055.95        126,476,000
# Bulgaria                                36,645.54          6,948,000
# Hungary                                 33,409.65          9,660,000
#
#                 Electricity Per Person (MWh) % Renewable  \
# Korea                                  22.86          9%
# Malta                                   5.05         11%
# ...

# %%
# Creates a graph of the bottom 10 countries based on renewables
worst_columns_for_plot.plot(kind='bar',
                            xlabel='Countries',
                            ylabel='Percentage of Electricity Produced in 2023',
                            title='Bottom 10 Countries Based on Renewables',
                            )

# Save as PNG file
plt.savefig('./output_data/bottom_10_bar.png')

# Shows the graph
plt.show()

# %% [markdown]
# ### Top 10 Performing Countries Based on Renewables Used for Electricity

# %%
# Creates a dataframe from the summary statistics to show the top 10 based on renewable percentage
best_percent_renewables = summary_statistics_2023.sort_values('% Renewable', ascending=False)

# Creating a copy for plotting later
best_columns_for_plot = best_percent_renewables[['% Renewable','% Non-Renewable Combustible','% Nuclear']].copy().iloc[:10,:]

# Format numbers for better readability
best_percent_renewables['Total Electricity Production (GWh)'] = best_percent_renewables['Total Electricity Production (GWh)'].map('{:,.2f}'.format)
best_percent_renewables['Country Population'] = best_percent_renewables['Country Population'].map('{:,.0f}'.format)
best_percent_renewables['% Renewable'] = best_percent_renewables['% Renewable'].map('{:.0f}%'.format)
best_percent_renewables['% Nuclear'] = best_percent_renewables['% Nuclear'].map('{:.0f}%'.format)
best_percent_renewables['% Non-Renewable Combustible'] = best_percent_renewables['% Non-Renewable Combustible'].map('{:.0f}%'.format)

# Display the first 10 rows in the dataframe
best_percent_renewables.head(10)
# Out:
#             Total Electricity Production (GWh) Country Population  \
# Iceland                              19,843.28            341,000
# Costa Rica                           11,418.22          5,094,000
# Norway                              153,910.63          5,421,000
# Luxembourg                            2,280.12            626,000
# Denmark                              33,758.68          5,792,000
# Brazil                              690,334.72        212,559,000
# New Zealand                          43,036.99          4,822,000
# Austria                              67,958.49          9,006,000
# Latvia                                5,915.44          1,886,000
# Portugal                             49,002.14         10,197,000
#
#              Electricity Per Person (MWh) % Renewable  \
# Iceland                             58.19        100%
# Costa Rica                           2.24        100%
# Norway                              28.39         99%
# ...

# %%
# Creates a graph of the bottom 10 countries based on renewables
best_columns_for_plot.plot(kind='bar',
                            xlabel='Countries',
                            ylabel='Percentage of Electricity Produced in 2023',
                            title='Top 10 Countries Based on Renewables',
                            )

# Save as PNG file
plt.savefig('./output_data/top_10_bar.png')

# Shows the graph
plt.show()

# %%
# Define mappings for renewable energy sources
renewables = ['Combustible Renewables', 'Hydro', 'Wind', 'Solar', 'Geothermal', 'Other Renewables']

# Filter DataFrame to include only rows corresponding to renewables
renewables_df = original_df[original_df['product'].isin(renewables)]

# Group data by country and renewable energy source, and calculate the sum of values for each group
renewables_sum_by_country = renewables_df.groupby(['country_name', 'product'])['value'].sum()

# Find the renewable energy source with the highest contribution for each country
most_popular_renewables_by_country = renewables_sum_by_country.groupby(level=0).idxmax().apply(lambda x: x[1])

print("Most popular renewables used by each country:")
most_popular_renewables_by_country
# Out:
# Most popular renewables used by each country:
# country_name
# Argentina                           Hydro
# Australia                            Wind
# Austria                             Hydro
# Belgium                              Wind
# Brazil                              Hydro
# Bulgaria                            Hydro
# Canada                              Hydro
# Chile                               Hydro
# China                               Hydro
# Colombia                            Hydro
# Costa Rica                          Hydro
# Croatia                             Hydro
# Cyprus                              Solar
# Czech Republic     Combustible Renewables
# Denmark                              Wind
# Estonia            Combustible Renewables
# Finland                             Hydro
# France                              Hydro
# Germany                              Wind
# Greece                               Wind
# Hungary            Combustible Renewables
# ...

# %%
# Plot the bar graph
most_popular_renewables_by_country.value_counts().plot(kind='bar', color='skyblue')

# Add labels
plt.title('Most Popular Renewables Used by Each Country')
plt.xlabel('Renewable Energy Source')
plt.ylabel('Number of Countries')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Save as PNG file
plt.savefig('./output_data/most_pop_renews.png')

# Show plot
plt.show()

# %%
# Filter raw dataframe for combustibles, renewables, and combustible renewables
total_combustible_df = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Total Combustible Fuels')]
combustible_renewables_df = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Combustible Renewables')]
total_renewables_df = original_df[(original_df['parameter']=='Net Electricity Production')&(original_df['product']=='Total Renewables (Hydro, Geo, Solar, Wind, Other)')]

# Rename columns 
total_combustible_df = total_combustible_df.rename(columns={'value':'Combustible Fuel'})
combustible_renewables_df = combustible_renewables_df.rename(columns={'value':'Combustible Renewables'})
total_renewables_df = total_renewables_df.rename(columns={'value':'Total Renewables'})

# Drop unneeded columns
total_combustible_df = total_combustible_df.drop(columns={'parameter','unit','product'})
combustible_renewables_df = combustible_renewables_df.drop(columns={'parameter','unit','product'})
total_renewables_df = total_renewables_df.drop(columns={'parameter','unit','product'})

# Merge Dataframes
all_combutibles_df = pd.merge(total_combustible_df, combustible_renewables_df)
main_df = pd.merge(all_combutibles_df, total_renewables_df)

# Create column with only non-renewable combustible fuel
main_df['Non-Renewables'] = main_df['Combustible Fuel']-main_df['Combustible Renewables']

# Create a column for the year
main_df['Year'] = main_df['date'].str.split('/').str[-1]

# Display merged data frame
main_df.head()
# Out:
#   country_name       date  Combustible Fuel  Year  Combustible Renewables  \
# 0    Australia  12/1/2023          13397.94  2023                  247.94
# 1      Austria  12/1/2023           1746.90  2023                  407.40
# 2      Belgium  12/1/2023           1521.76  2023                  200.90
# 3       Canada  12/1/2023          11574.95  2023                  928.45
# 4        Chile  12/1/2023           2099.87  2023                  386.20
#
#    Total Renewables  Non-Renewables
# 0           9496.20        13149.99
# 1           5443.14         1339.50
# 2           2556.33         1320.86
# 3          37760.48        10646.50
# 4           6021.32         1713.67

# %%
# Create groupby for fossil and renewable based on country and year
fossil_grouped_by_country_year = main_df.groupby(['country_name','Year'])['Non-Renewables'].sum()
renew_grouped_by_country_year = main_df.groupby(['country_name','Year'])['Total Renewables'].sum()

pd.set_option('display.float_format', lambda x: '%.2f' % x)

# renewables_grouped_by_country_year = main_df.groupby(['country_name','Year'])['Total Renewables'].sum()
fossil_renew_grouped_by_country_year = pd.DataFrame({'Non-Renewables' : fossil_grouped_by_country_year,
                                                     'Renewables': renew_grouped_by_country_year})
fossil_renew_grouped_by_country_year
# Out:
#                     Non-Renewables  Renewables
# country_name  Year
# Argentina     2015        97379.18    33567.57
#               2016       100338.11    31013.89
#               2017        98852.40    33292.21
#               2018        98021.59    34652.22
#               2019        89968.76    34524.08
# ...                            ...         ...
# United States 2019      2606126.95   775304.57
#               2020      2450705.23   806946.32
#               2021      2532061.10   873123.23
#               2022      2581065.98   975828.84
#               2023      2519199.59   958799.74
#
# [589 rows x 2 columns]

# %%
# Create a column for fossil to renewable ratio
fossil_renew_grouped_by_country_year['Non-Renewable to Renewable Ratio'] = fossil_renew_grouped_by_country_year['Non-Renewables']/fossil_renew_grouped_by_country_year['Renewables']
fossil_renew_grouped_by_country_year = fossil_renew_grouped_by_country_year.reset_index()

# Display dataframe
fossil_renew_grouped_by_country_year
# Out:
#       country_name  Year  Non-Renewables  Renewables  \
# 0        Argentina  2015        97379.18    33567.57
# 1        Argentina  2016       100338.11    31013.89
# 2        Argentina  2017        98852.40    33292.21
# 3        Argentina  2018        98021.59    34652.22
# 4        Argentina  2019        89968.76    34524.08
# ..             ...   ...             ...         ...
# 584  United States  2019      2606126.95   775304.57
# 585  United States  2020      2450705.23   806946.32
# 586  United States  2021      2532061.10   873123.23
# 587  United States  2022      2581065.98   975828.84
# 588  United States  2023      2519199.59   958799.74
#
#      Non-Renewable to Renewable Ratio
# 0                                2.90
# 1                                3.24
# 2                                2.97
# 3                                2.83
# 4                                2.61
# ..                                ...
# 584                              3.36
# ...

# %%
# Filter for only the most recent year
fossil_renew_grouped_by_country_2023 = fossil_renew_grouped_by_country_year[fossil_renew_grouped_by_country_year['Year']=='2023']

# Display dataframe
fossil_renew_grouped_by_country_2023
# Out:
#         country_name  Year  Non-Renewables  Renewables  \
# 8          Argentina  2023        80135.75    41461.54
# 22         Australia  2023       162879.67    98690.91
# 36           Austria  2023        10498.63    57444.95
# 50           Belgium  2023        19934.84    27160.11
# 59            Brazil  2023        55046.20   621612.97
# 68          Bulgaria  2023        11747.49     9529.01
# 82            Canada  2023       110996.17   418864.96
# 96             Chile  2023        31057.63    59464.33
# 105            China  2023      5789533.49  2896375.84
# 115         Colombia  2023        29173.02    57389.76
# 118       Costa Rica  2023           18.86    11399.36
# 127          Croatia  2023         4957.03    12255.59
# 136           Cyprus  2023         4042.90     1081.64
# 150   Czech Republic  2023        30646.37    11042.95
# 164          Denmark  2023         2934.44    30824.23
# 178          Estonia  2023         2506.25     2086.32
# ...

# %%
# Create plot
plt.figure(figsize=(12, 6))
plt.bar(fossil_renew_grouped_by_country_2023['country_name'], fossil_renew_grouped_by_country_2023['Non-Renewable to Renewable Ratio'], color='skyblue')

# Add labels
plt.title('Ratio of Non-Renewables to Renewables for Electricity Generation in 2023')
plt.xlabel('Country')
plt.ylabel('Ratio')
plt.xticks(ticks=fossil_renew_grouped_by_country_2023['country_name'], labels=fossil_renew_grouped_by_country_2023['country_name'], rotation=45, ha='right')

# Adjust x limits for better viewablility
plt.xlim(-1,47)
plt.tight_layout()

# Save plot as PNG file
plt.savefig('./output_data/bar_ratio_non_vs_renew.png')

# Show plot
plt.show()

# %% [markdown]
# Malta index number 368 has the worst ratio of fossil fuel to renewables in 2023 at 10.36, while Costa Rica index number 118 has the best at 0 as they use 11399.36 GWh of renewables to just 18.86GWh of fossil fuels.

# %% [markdown]
# # What do we predict the future non-renewable fuel to renewable ratio will look like for the U.S.?

# %%
# Find the Ratio for the United States
us_df = fossil_renew_grouped_by_country_year[fossil_renew_grouped_by_country_year['country_name']== 'United States'].copy()
us_df['Year'] = us_df['Year'].astype(int)
us_df
# Out:
#       country_name  Year  Non-Renewables  Renewables  \
# 575  United States  2010      2892413.77   456142.22
# 576  United States  2011      2799552.61   542625.39
# 577  United States  2012      2781252.49   522776.51
# 578  United States  2013      2750232.18   550184.83
# 579  United States  2014      2753537.36   568864.64
# 580  United States  2015      2729977.81   576983.19
# 581  United States  2016      2661035.69   647498.93
# 582  United States  2017      2547633.86   728586.91
# 583  United States  2018      2674405.28   750808.08
# 584  United States  2019      2606126.95   775304.57
# 585  United States  2020      2450705.23   806946.32
# 586  United States  2021      2532061.10   873123.23
# 587  United States  2022      2581065.98   975828.84
# 588  United States  2023      2519199.59   958799.74
#
#      Non-Renewable to Renewable Ratio
# 575                              6.34
# 576                              5.16
# 577                              5.32
# ...

# %%
# set x and y values
x_values = us_df['Year']
y_values = us_df['Non-Renewable to Renewable Ratio']

# Create scatter plot
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, color = 'blue', edgecolors= 'black')

# Add linear regression to scatterplot
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regression_line = x_values * slope + intercept

ax.plot(x_values, regression_line, color='red', label='Linear Regression')
equation = f'y = {slope:.2f}x + {intercept:.2f}'

plt.text(x_values.iloc[0], y_values.iloc[0], equation, fontsize=10, color='green', ha = 'left', va = 'top')

# Add labels/title
ax.set_xlabel('Year')
ax.set_ylabel('Non-Renewables to Renewables Ratio')
ax.set_title("United States Non-Renewables to Renewables Ratios Between 2010 to 2023")
ax.set_xticks(ticks=x_values,labels=x_values,rotation=45)

# Save image to output folder
fig.savefig('./output_data/future_ratio_us.png')


# Show Graph
plt.show()

# %%
# Using the equation for the line, predict what the ratio will be in 10 years (2023)
future_ratio = -0.27 * 2033 + 549.07
print(f'Based on the model above, we predict a ratio of {round(future_ratio, 2)} by 2033 for the United States.')
# Out:
# Based on the model above, we predict a ratio of 0.16 by 2033 for the United States.

# %%
# United States Fossils and Renwables over the years
us_non_vs_rew_df = fossil_renew_grouped_by_country_year[fossil_renew_grouped_by_country_year['country_name']=='United States'].drop(columns=['country_name', 'Non-Renewable to Renewable Ratio']).set_index('Year')
us_non_vs_rew_df.plot(kind='bar')
plt.title('United States Non-Renewable vs Renewables')

# Save plot as PNG
fig.savefig('./output_data/US_non_renewables_vs_renewables_ratios.png')

# Display Plot
plt.show()

# %%
#Calculate China's totals
china_df = fossil_renew_grouped_by_country_year[fossil_renew_grouped_by_country_year['country_name']== 'China'].copy()
china_df['Year'] = china_df['Year'].astype(int)
china_df
# Out:
#     country_name  Year  Non-Renewables  Renewables  \
# 97         China  2015      4021548.83  1375240.20
# 98         China  2016      4171524.19  1501895.28
# 99         China  2017      4491498.88  1636817.74
# 100        China  2018      4684047.63  1809711.23
# 101        China  2019      4802383.28  1989526.16
# 102        China  2020      4871564.64  2154750.45
# 103        China  2021      5331900.07  2349766.04
# 104        China  2022      5410899.57  2613364.30
# 105        China  2023      5789533.49  2896375.84
#
#      Non-Renewable to Renewable Ratio
# 97                               2.92
# 98                               2.78
# 99                               2.74
# 100                              2.59
# 101                              2.41
# 102                              2.26
# 103                              2.27
# 104                              2.07
# 105                              2.00

# %%
# set x and y values
x_values = china_df['Year']
y_values = china_df['Non-Renewable to Renewable Ratio']

# Create scatter plot
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, color = 'blue', edgecolors= 'black')

# Add linear regression to scatterplot
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regression_line = x_values * slope + intercept

ax.plot(x_values, regression_line, color='red', label='Linear Regression')
equation = f'y = {slope:.2f}x + {intercept:.2f}'

plt.text(china_df['Year'].iloc[0], china_df['Non-Renewable to Renewable Ratio'].iloc[0], equation, fontsize=10, color='green', ha = 'left', va = 'top')

# Add labels/title
ax.set_xlabel('Year')
ax.set_ylabel('Fossil to Renewables Ratio')
ax.set_xlim(2015, 2023)
ax.set_title("China Non-Renewables to Renewables Ratios Between 2015 to 2023")
ax.set_xticks(range(2015,2024))

# Rotate x-axis tick labels by 45 degrees
ax.set_xticklabels(ax.get_xticks(), rotation=45)

# Save image to output folder
fig.savefig('./output_data/China_fossil_to_renewables_ratios')

# Show Graph
plt.show()

# %%
# Using the equation for the line, predict what the ratio will be in 10 years (2023)
china_future_ratio = -0.12*2033 + 241.36
print(f'Based on the model above, we predict a ratio of {round(china_future_ratio, 2)} by 2033 for China.')
# Out:
# Based on the model above, we predict a ratio of -2.6 by 2033 for China.
